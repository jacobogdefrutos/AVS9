# %%
from ultralytics import YOLO
import numpy as np
import torch
import cv2

# %%
model = YOLO("yolov8s.pt")
model.train(data='/home/jacobo15defrutos/AVS9/config.yaml',epochs=50,imgsz=640,batch=25)
# Out:
# New https://pypi.org/project/ultralytics/8.0.212 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.13 torch-2.0.1 CPU (AMD EPYC 7B13)
# ...

# %%
model = YOLO("yolov8s.pt")
model.train(data='/home/jacobo15defrutos/AVS9/config.yaml',epochs=50,imgsz=640,batch=25)
# Out:
# New https://pypi.org/project/ultralytics/8.0.212 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.13 torch-2.0.1 CPU (AMD EPYC 7B13)
# ...
