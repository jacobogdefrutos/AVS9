# %%
from ultralytics import YOLO
import numpy as np
import torch
import cv2

# %%
model = YOLO("yolov8s.pt")
model.train(data='/home/jacobo15defrutos/AVS9/config.yaml',epochs=10,imgsz=640)
# Out:
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 220MB/s]
# New https://pypi.org/project/ultralytics/8.0.210 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.209 🚀 Python-3.10.13 torch-2.0.1 CPU (AMD EPYC 7B13)
# ...
